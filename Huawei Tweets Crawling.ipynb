# %%
from twitterscraper import query_tweets
import datetime as dt
import pandas as pd
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 6.1; x64; fr; rv:1.9.2.13) Gecko/20101203 Firebird/3.6.13'}

# %%
NameOfCompanies = ["@huawei", "@HuaweiMobile", "HuaweiServices","matebook"]
companies = []

# %%
i=0
while i < len(NameOfCompanies):   
    begin_date = dt.date(2019,10,1)
    end_date = dt.date(2020,2,1)
    limit = 0
    lang = "english"
    CompanyTweets = query_tweets(NameOfCompanies[i], limit=limit, begindate=begin_date, enddate=end_date, lang=lang)
    companies.append(CompanyTweets)
    i= i+1
else:
    print(NameOfCompanies[0])
    print(NameOfCompanies[1])
    print(NameOfCompanies[2])
    print(NameOfCompanies[3])
    print("Finally finished!")
# Out:
# INFO: queries: ['@huawei since:2019-10-01 until:2019-10-07', '@huawei since:2019-10-07 until:2019-10-13', '@huawei since:2019-10-13 until:2019-10-19', '@huawei since:2019-10-19 until:2019-10-25', '@huawei since:2019-10-25 until:2019-10-31', '@huawei since:2019-10-31 until:2019-11-06', '@huawei since:2019-11-06 until:2019-11-13', '@huawei since:2019-11-13 until:2019-11-19', '@huawei since:2019-11-19 until:2019-11-25', '@huawei since:2019-11-25 until:2019-12-01', '@huawei since:2019-12-01 until:2019-12-07', '@huawei since:2019-12-07 until:2019-12-13', '@huawei since:2019-12-13 until:2019-12-19', '@huawei since:2019-12-19 until:2019-12-26', '@huawei since:2019-12-26 until:2020-01-01', '@huawei since:2020-01-01 until:2020-01-07', '@huawei since:2020-01-07 until:2020-01-13', '@huawei since:2020-01-13 until:2020-01-19', '@huawei since:2020-01-19 until:2020-01-25', '@huawei since:2020-01-25 until:2020-02-01']
# INFO: Got 690 tweets (690 new).
# INFO: Got 1373 tweets (683 new).
# INFO: Got 2060 tweets (687 new).
# INFO: Got 2714 tweets (654 new).
# INFO: Got 3392 tweets (678 new).
# INFO: Got 4063 tweets (671 new).
# INFO: Got 4694 tweets (631 new).
# INFO: Got 5348 tweets (654 new).
# INFO: Got 6084 tweets (736 new).
# INFO: Got 6756 tweets (672 new).
# INFO: Got 7487 tweets (731 new).
# INFO: Got 8217 tweets (730 new).
# INFO: Got 8917 tweets (700 new).
# INFO: Got 9631 tweets (714 new).
# INFO: Got 10296 tweets (665 new).
# INFO: Got 10998 tweets (702 new).
# INFO: Got 11717 tweets (719 new).
# INFO: Got 12443 tweets (726 new).
# INFO: Got 13135 tweets (692 new).
# INFO: Got 13861 tweets (726 new).
# INFO: queries: ['@HuaweiMobile since:2019-10-01 until:2019-10-07', '@HuaweiMobile since:2019-10-07 until:2019-10-13', '@HuaweiMobile since:2019-10-13 until:2019-10-19', '@HuaweiMobile since:2019-10-19 until:2019-10-25', '@HuaweiMobile since:2019-10-25 until:2019-10-31', '@HuaweiMobile since:2019-10-31 until:2019-11-06', '@HuaweiMobile since:2019-11-06 until:2019-11-13', '@HuaweiMobile since:2019-11-13 until:2019-11-19', '@HuaweiMobile since:2019-11-19 until:2019-11-25', '@HuaweiMobile since:2019-11-25 until:2019-12-01', '@HuaweiMobile since:2019-12-01 until:2019-12-07', '@HuaweiMobile since:2019-12-07 until:2019-12-13', '@HuaweiMobile since:2019-12-13 until:2019-12-19', '@HuaweiMobile since:2019-12-19 until:2019-12-26', '@HuaweiMobile since:2019-12-26 until:2020-01-01', '@HuaweiMobile since:2020-01-01 until:2020-01-07', '@HuaweiMobile since:2020-01-07 until:2020-01-13', '@HuaweiMobile since:2020-01-13 until:2020-01-19', '@HuaweiMobile since:2020-01-19 until:2020-01-25', '@HuaweiMobile since:2020-01-25 until:2020-02-01']
# INFO: Got 19 tweets (19 new).
# INFO: Got 39 tweets (20 new).
# INFO: Got 58 tweets (19 new).
# INFO: Got 77 tweets (19 new).
# INFO: Got 97 tweets (20 new).
# INFO: Got 117 tweets (20 new).
# INFO: Got 136 tweets (19 new).
# INFO: Got 156 tweets (20 new).
# INFO: Got 176 tweets (20 new).
# INFO: Got 196 tweets (20 new).
# INFO: Got 216 tweets (20 new).
# INFO: Got 235 tweets (19 new).
# INFO: Got 254 tweets (19 new).
# INFO: Got 274 tweets (20 new).
# INFO: Got 294 tweets (20 new).
# INFO: Got 314 tweets (20 new).
# INFO: Got 334 tweets (20 new).
# INFO: Got 354 tweets (20 new).
# INFO: Got 374 tweets (20 new).
# INFO: Got 394 tweets (20 new).
# INFO: queries: ['HuaweiServices since:2019-10-01 until:2019-10-07', 'HuaweiServices since:2019-10-07 until:2019-10-13', 'HuaweiServices since:2019-10-13 until:2019-10-19', 'HuaweiServices since:2019-10-19 until:2019-10-25', 'HuaweiServices since:2019-10-25 until:2019-10-31', 'HuaweiServices since:2019-10-31 until:2019-11-06', 'HuaweiServices since:2019-11-06 until:2019-11-13', 'HuaweiServices since:2019-11-13 until:2019-11-19', 'HuaweiServices since:2019-11-19 until:2019-11-25', 'HuaweiServices since:2019-11-25 until:2019-12-01', 'HuaweiServices since:2019-12-01 until:2019-12-07', 'HuaweiServices since:2019-12-07 until:2019-12-13', 'HuaweiServices since:2019-12-13 until:2019-12-19', 'HuaweiServices since:2019-12-19 until:2019-12-26', 'HuaweiServices since:2019-12-26 until:2020-01-01', 'HuaweiServices since:2020-01-01 until:2020-01-07', 'HuaweiServices since:2020-01-07 until:2020-01-13', 'HuaweiServices since:2020-01-13 until:2020-01-19', 'HuaweiServices since:2020-01-19 until:2020-01-25', 'HuaweiServices since:2020-01-25 until:2020-02-01']
# INFO: Got 2 tweets (2 new).
# INFO: Got 10 tweets (8 new).
# INFO: Got 20 tweets (10 new).
# INFO: Got 29 tweets (9 new).
# INFO: Got 34 tweets (5 new).
# INFO: Got 38 tweets (4 new).
# INFO: Got 39 tweets (1 new).
# INFO: Got 40 tweets (1 new).
# INFO: Got 42 tweets (2 new).
# INFO: Got 46 tweets (4 new).
# INFO: Got 47 tweets (1 new).
# INFO: Got 55 tweets (8 new).
# INFO: Got 58 tweets (3 new).
# INFO: Got 64 tweets (6 new).
# INFO: Got 82 tweets (18 new).
# INFO: Got 83 tweets (1 new).
# INFO: Got 84 tweets (1 new).
# INFO: Got 84 tweets (0 new).
# INFO: Got 84 tweets (0 new).
# INFO: Got 84 tweets (0 new).
# INFO: queries: ['matebook since:2019-10-01 until:2019-10-07', 'matebook since:2019-10-07 until:2019-10-13', 'matebook since:2019-10-13 until:2019-10-19', 'matebook since:2019-10-19 until:2019-10-25', 'matebook since:2019-10-25 until:2019-10-31', 'matebook since:2019-10-31 until:2019-11-06', 'matebook since:2019-11-06 until:2019-11-13', 'matebook since:2019-11-13 until:2019-11-19', 'matebook since:2019-11-19 until:2019-11-25', 'matebook since:2019-11-25 until:2019-12-01', 'matebook since:2019-12-01 until:2019-12-07', 'matebook since:2019-12-07 until:2019-12-13', 'matebook since:2019-12-13 until:2019-12-19', 'matebook since:2019-12-19 until:2019-12-26', 'matebook since:2019-12-26 until:2020-01-01', 'matebook since:2020-01-01 until:2020-01-07', 'matebook since:2020-01-07 until:2020-01-13', 'matebook since:2020-01-13 until:2020-01-19', 'matebook since:2020-01-19 until:2020-01-25', 'matebook since:2020-01-25 until:2020-02-01']
# INFO: Got 20 tweets (20 new).
# INFO: Got 40 tweets (20 new).
# INFO: Got 57 tweets (17 new).
# INFO: Got 76 tweets (19 new).
# INFO: Got 96 tweets (20 new).
# INFO: Got 116 tweets (20 new).
# INFO: Got 136 tweets (20 new).
# INFO: Got 156 tweets (20 new).
# INFO: Got 176 tweets (20 new).
# INFO: Got 195 tweets (19 new).
# INFO: Got 215 tweets (20 new).
# INFO: Got 231 tweets (16 new).
# INFO: Got 248 tweets (17 new).
# INFO: Got 268 tweets (20 new).
# INFO: Got 288 tweets (20 new).
# INFO: Got 308 tweets (20 new).
# INFO: Got 327 tweets (19 new).
# INFO: Got 346 tweets (19 new).
# INFO: Got 365 tweets (19 new).
# INFO: Got 385 tweets (20 new).
# @huawei
# @HuaweiMobile
# HuaweiServices
# matebook
# Finally finished!

# %%
dfNames = ["@huawei", "@HuaweiMobile", "HuaweiServices","matebook"]

# %%
i=0
for company in companies:
    dfNames[i] = pd.DataFrame(t.__dict__ for t in  company)
    i = i+1

# %%
huawei = dfNames[0]
HuaweiMobile = dfNames[1]
HuaweiServices = dfNames[2]
matebook = dfNames[3]

# %%
huaweiTweets = huawei.append([HuaweiMobile,HuaweiServices,matebook])

# %%
huaweiTweets.reset_index(inplace=True, drop=True)

# %%
huaweiTweets.head()
# Out:
#        screen_name       username              user_id             tweet_id  \
# 0     AshrafSaroor  Saroor Ashraf  1073466932052004864  1209986413204299776
# 1         kh3media      خالد يونس            867137952  1209986138624143360
# 2     DeanMThomson           Dean            892032913  1209986027064111104
# 3  Pinhead49942031        Pinhead  1202334851128582147  1209985508371251202
# 4    Oneironautist     oneironaut           2591545188  1209983707693637637
#
#                                      tweet_url           timestamp  \
# 0     /AshrafSaroor/status/1209986413204299776 2019-12-25 23:56:56
# 1         /kh3media/status/1209986138624143360 2019-12-25 23:55:50
# 2     /DeanMThomson/status/1209986027064111104 2019-12-25 23:55:23
# 3  /Pinhead49942031/status/1209985508371251202 2019-12-25 23:53:20
# 4    /Oneironautist/status/1209983707693637637 2019-12-25 23:46:10
#
#    timestamp_epochs                                               text  \
# 0        1577318216  Its Christmas time  @Huawei @HonorEU #Huawei #...
# 1        1577318150  How to submit an idea for a new generation for...
# 2        1577318123  It means I’m worried about big businesses who ...
# 3        1577318000              you can't even access google in china
# 4        1577317570                                   #stolentech #pla
#
#                                            text_html links  ... has_media  \
# 0  <p class="TweetTextSize js-tweet-text tweet-te...    []  ...      True
# 1  <p class="TweetTextSize js-tweet-text tweet-te...    []  ...     False
# 2  <p class="TweetTextSize js-tweet-text tweet-te...    []  ...     False
# 3  <p class="TweetTextSize js-tweet-text tweet-te...    []  ...     False
# 4  <p class="TweetTextSize js-tweet-text tweet-te...    []  ...     False
#
#                                             img_urls video_url likes  \
# 0  [https://pbs.twimg.com/media/EMq8OGJXYAAV8lQ.jpg]               0
# 1                                                 []               0
# 2                                                 []               0
# 3                                                 []               0
# 4                                                 []               0
#
#    retweets  replies  is_replied  is_reply_to      parent_tweet_id  \
# 0         0        0       False         True  1209932731263655936
# 1         0        0       False         True  1209448831340802049
# 2         0        0       False         True  1207937262521962501
# 3         0        0       False         True  1204701418763911168
# 4         0        1        True         True  1209448831340802049
#
#                                       reply_to_users
# 0  [{'screen_name': 'HuaweiMobile', 'user_id': '1...
# 1  [{'screen_name': 'Huawei', 'user_id': '9804721...
# 2  [{'screen_name': 'Huawei', 'user_id': '9804721...
# 3  [{'screen_name': 'Huawei', 'user_id': '9804721...
# 4  [{'screen_name': 'Huawei', 'user_id': '9804721...
#
# [5 rows x 21 columns]

# %%
huaweiTweets.shape
# Out:
# (14724, 21)

# %%
huaweiTweets.to_csv('data/HuaweiTweets.csv',index=False)
